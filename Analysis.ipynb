# %%
import pandas as pd
dataset1 = pd.read_csv('Dataset/Disease burden estimater.csv')
dataset1
# Out:
#                        Category  \
# 0         Communicable Diseases
# 1         Communicable Diseases
# 2         Communicable Diseases
# 3         Communicable Diseases
# 4         Communicable Diseases
# 5         Communicable Diseases
# 6   Non-Communicable Conditions
# 7   Non-Communicable Conditions
# 8   Non-Communicable Conditions
# 9   Non-Communicable Conditions
# 10  Non-Communicable Conditions
# 11  Non-Communicable Conditions
# 12       Other Non-Communicable
#
#               Disease/Health Condition (Base Year)  Estimate of Cases/lakh  \
# 0                              Tuberculosis (2000)                   85.00
# 1                                  HIV/AIDS (2004)                   51.00
# 2            Diarrhoeal Diseases Episodes per Year                  760.00
# 3   Malaria and other Vector Borne Diseases (2004)                   20.37
# 4                                   Leprosy (2004)                    3.67
# ...

# %%
import dtale
dtale.show(dataset1)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-SU9ADVF:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dataset2 = pd.read_csv('Dataset/Internet user man.csv')
dataset2
# Out:
#              State  Urban  Rural
# 0              A&N   54.6   41.1
# 1   ANDHRA PRADESH   65.1   41.5
# 2            ASSAM   67.4   37.8
# 3            BIHAR   58.4   39.4
# 4        DNH & D V   76.2   61.3
# 5              GOA   86.1   76.6
# 6           GUJRAT   72.9   48.0
# 7               HP   83.7   65.1
# 8            J & K   79.4   68.8
# 9        KARNATAKA   71.5   55.6
# 10          KERALA   78.3   74.2
# 11     LAKSHADWEEP   81.5   77.0
# 12          LADAKH   82.9   64.3
# 13     MAHARASHTRA   76.8   47.2
# 14       MEGHALAYA   59.2   38.5
# 15         MANIPUR   81.5   68.2
# 16         MIZORAM   92.7   63.9
# 17        NAGALAND   81.0   55.2
# 18          SIKKIM   94.2   69.5
# 19       TELANGANA   72.3   46.7
# 20         TRIPURA   47.0   45.2
# 21     WEST BENGAL   34.6   38.3

# %%
import dtale
dtale.show(dataset2)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-SU9ADVF:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dataset3 = pd.read_csv('Dataset/Internet user women.csv')
dataset3
# Out:
#              State  Women   Men
# 0              A&N   34.8  46.5
# 1   ANDHRA PRADESH   21.0  48.8
# 2            ASSAM   28.2  42.3
# 3            BIHAR   20.6  43.6
# 4        DNH & D V   36.7  68.3
# 5              GOA   73.7  82.9
# 6           GUJRAT   30.8  58.9
# 7               HP   49.7  67.9
# 8            J & K   43.3  72.0
# 9        KARNATAKA   35.0  62.4
# 10          KERALA   61.1  76.1
# 11     LAKSHADWEEP   56.4  80.3
# 12          LADAKH   56.4  67.8
# 13     MAHARASHTRA   38.0  61.5
# 14       MEGHALAYA   34.7  42.1
# 15         MANIPUR   44.8  73.9
# 16         MIZORAM   67.6  79.7
# 17        NAGALAND   49.9  64.6
# 18          SIKKIM   76.7  78.2
# 19       TELANGANA   26.5  57.4
# 20         TRIPURA   22.9  45.7
# 21     WEST BENGAL   25.5  46.7

# %%
import dtale
dtale.show(dataset3)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-SU9ADVF:40000/dtale/iframe/3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dataset4 = pd.read_csv('Dataset/List of hospitals.csv')
dataset4
# Out:
#            cityName                                       hospitalName  \
# 0          Agartala  Society for Tripura Medical College & Dr. B.R....
# 1         Ahmedabad  Asian Bariatrics Ahmedabad Bariatrics & Cosmet...
# 2         Ahmedabad  Dr. Maitry M. Shah Dental Clinic & Implant Centre
# 3         Ahmedabad            AHMEDABAD INSTITUTE OF MEDICAL SERVICES
# 4         Ahmedabad                           RAGHUDEEP EYE CENTRE LLP
# ...             ...                                                ...
# 1490  Visakhapatnam  INDUS HOSPITALS A UNIT OF VASUGAN MEDICLA SPEC...
# 1491  Visakhapatnam  MAHATMA GANDHI CANCER & RESEARCH INSTITUTE A U...
# 1492  Visakhapatnam  CARE HOSPITALS (VISAKHA HOSPITALS AND DIAGNOST...
# 1493  Visakhapatnam  KALA HOSPITALS PRIVATE LIMITED 47-1-104 DWARAK...
# 1494  Visakhapatnam  QUEENS NRI HOSPITAL A UNIT OF CHALASANI HOSPIT...
#
#                                         hospitalAddress
# 0     Society for Tripura Medical College & Dr. B.R....
# ...

# %%
import dtale
dtale.show(dataset4)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-SU9ADVF:40000/dtale/iframe/4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dataset5 = pd.read_csv('Dataset/Litracy rate.csv')
dataset5.head()
# Out:
#   Category Country/ States/ Union Territories Name  \
# 0  Country                                   INDIA
# 1    State                          Andhra Pradesh
# 2    State                       Arunachal Pradesh
# 3    State                                   Assam
# 4    State                                   Bihar
#
#    Literacy Rate (Persons) - Total - 2001  \
# 0                                    64.8
# 1                                    60.5
# 2                                    54.3
# 3                                    63.3
# 4                                    47.0
#
#    Literacy Rate (Persons) - Total - 2011  \
# 0                                    73.0
# 1                                    67.0
# 2                                    65.4
# 3                                    72.2
# 4                                    61.8
#
#    Literacy Rate (Persons) - Rural - 2001  \
# 0                                    58.7
# 1                                    54.5
# ...

# %%
import dtale
dtale.show(dataset5)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-SU9ADVF:40000/dtale/iframe/5"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dataset6 = pd.read_csv('Dataset/Population in state.csv')
dataset6.head()
# Out:
#    S. No      India / State  Total Population (in lakh)  \
# 0  India              India                    12108.55
# 1      1     Andhra Pradesh                      493.87
# 2      2  Arunachal Pradesh                       13.84
# 3      3              Assam                      312.06
# 4      4              Bihar                     1040.99
#
#    ST Population (in lakh)  \
# 0                  1045.46
# 1                    26.31
# 2                     9.52
# 3                    38.84
# 4                    13.37
#
#    % STs in India/ State to total population of India/ State  \
# 0                                                8.6
# 1                                                5.3
# 2                                               68.8
# 3                                               12.4
# 4                                                1.3
#
#    % STs in the State to total ST population in India
# 0                                                NaN
# ...

# %%
update_df = dataset6.drop(dataset6.index[0])
update_df.head()
# Out:
#   S. No      India / State  Total Population (in lakh)  \
# 1     1     Andhra Pradesh                      493.87
# 2     2  Arunachal Pradesh                       13.84
# 3     3              Assam                      312.06
# 4     4              Bihar                     1040.99
# 5     5       Chhattisgarh                      255.45
#
#    ST Population (in lakh)  \
# 1                    26.31
# 2                     9.52
# 3                    38.84
# 4                    13.37
# 5                    78.23
#
#    % STs in India/ State to total population of India/ State  \
# 1                                                5.3
# 2                                               68.8
# 3                                               12.4
# 4                                                1.3
# 5                                               30.6
#
#    % STs in the State to total ST population in India
# 1                                                2.5
# ...

# %%
import dtale
dtale.show(update_df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-SU9ADVF:40000/dtale/iframe/6"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dataset6 = pd.read_csv('Dataset/Rular Doctor at primiary health center.csv')
dataset6.head()
# Out:
#                   State/UT  Required1 (R)  Sanctioned (S)  In Position (P)  \
# 0           Andhra Pradesh          223.0           409.0            389.0
# 1  Arunachal Pradesh # (+)           97.0             NaN             92.0
# 2                    Assam          282.0             NaN            139.0
# 3                  Bihar##            6.0             1.0              1.0
# 4             Chhattisgarh          403.0           365.0            170.0
#
#   Vacant (S-P) Shortfall (R-P)
# 0           20         Surplus
# 1          NaN               5
# 2          NaN             143
# 3            0               5
# 4          195             233

# %%
import dtale
dtale.show(dataset6)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-SU9ADVF:40000/dtale/iframe/7"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dataset7 = pd.read_csv('Dataset/State wise death.csv',encoding='cp1252')
dataset7.head()
# Out:
#        States/UTs  Year         CrimeHead  Male_below 14 years  \
# 0  Andhra Pradesh  2014         Avalanche                    0
# 1  Andhra Pradesh  2014  Exposure to cold                    0
# 2  Andhra Pradesh  2014           Cyclone                    1
# 3  Andhra Pradesh  2014           Tornado                    0
# 4  Andhra Pradesh  2014           Tsunami                    0
#
#    Male_14 and above – below 18 years  Male_18 and above – below 30 years  \
# 0                                   0                                   0
# 1                                   0                                   0
# 2                                   4                                   8
# 3                                   0                                   0
# 4                                   0                                   0
#
#    Male_30 and above – below 45 years  Male_45 and above – below 60 years  \
# ...

# %%
import dtale
dtale.show(dataset7)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-SU9ADVF:40000/dtale/iframe/8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dataset7 = pd.read_csv('Dataset/State wise some disease.csv')
dataset7.head()
import dtale
dtale.show(dataset7)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-SU9ADVF:40000/dtale/iframe/9"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dataset8 = pd.read_csv('Dataset/State wise diabetes disease.csv')
dataset8.head()
import dtale
dtale.show(dataset8)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-SU9ADVF:40000/dtale/iframe/13"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
dataset9 = pd.read_csv('Dataset/indian census/india-districts-census-2011.csv')
dataset9.head()
import dtale
dtale.show(dataset9)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-SU9ADVF:40000/dtale/iframe/15"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Exception occurred while processing request: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
# Traceback (most recent call last):
#   File "C:\Users\talka\anaconda3\lib\site-packages\dtale\views.py", line 121, in _handle_exceptions
#     return func(*args, **kwargs)
#   File "C:\Users\talka\anaconda3\lib\site-packages\dtale\views.py", line 2672, in get_column_analysis
#     return jsonify(**analysis.build())
#   File "C:\Users\talka\anaconda3\lib\site-packages\dtale\column_analysis.py", line 137, in build
#     return_data, code = self.analysis.build(self)
#   File "C:\Users\talka\anaconda3\lib\site-packages\dtale\column_analysis.py", line 181, in build
# ...
